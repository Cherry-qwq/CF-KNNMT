# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号
# 假设的数据
x = [3,5,6,7,8,9,10,11,13,15]  # 横轴数据
bleua1 = [44.40,45.58,46.23,46.05,45.89,45.99,46.09,45.97,45.95,46.00]  # 第一条线的纵轴数据
bleua2 = [46.63]*len(x) # 第二条线的纵轴数据

bleub1 = [61.11,61.24,61.35,61.45,61.41,61.38,61.31,61.28,61.22,61.00]
bleub2 = [61.69]*len(x)

bleuc1 = [19.02,19.90,19.92,20.28,20.33,20.48,20.39,20.65,20.43,20.68]
bleuc2 = [20.74]*len(x)

bleud1 = [53.56,54.38,53.85,53.94,53.79,54.16,54.25,54.17,54.09,54.32]
bleud2 = [54.76]*len(x)


fig, axs = plt.subplots(2, 2)

# 创建折线图
axs[0,0].plot(x, bleua1, label='Fixed k-value ', marker='o')  # 第一条线
axs[0,0].plot(x, bleua2, label='Dynamic k-value', linestyle='--')  # 第二条线

# 添加标题和轴标签
axs[0,0].set_title('IT')
# axs[0,0].xlabel('k')
# axs[0,0].ylabel('bleu')

axs[0,1].plot(x, bleub1, label='Fixed k-value ', marker='o')  # 第一条线
axs[0,1].plot(x, bleub2, label='Dynamic k-value', linestyle='--')  # 第二条线
axs[0,1].set_title('Law')

axs[1,0].plot(x, bleuc1, label='Fixed k-value ', marker='o')  # 第一条线
axs[1,0].plot(x, bleuc2, label='Dynamic k-value', linestyle='--')  # 第二条线
axs[1,0].set_title('Koran')

axs[1,1].plot(x, bleud1, label='Fixed k-value ', marker='o')  # 第一条线
axs[1,1].plot(x, bleud2, label='Dynamic k-value', linestyle='--')  # 第二条线

axs[1,1].set_title('Medical')
# 显示图例
plt.subplots_adjust(hspace=0.3, wspace=0.3)
plt.legend()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号
# 假设的数据
x = [0.2,0.3,0.5,0.6,0.8,0.9,1,1.2,1.4,1.5]#,2  # 横轴数据
#IT
bleua1 = [45.73,45.73,45.80,45.77,45.88,45.82,45.89,46.01,46.04,46.00]#,45.38  # 第一条线的纵轴数据
bleua2 = [45.6]*len(x) # 第二条线的纵轴数据
#LAW
bleub1 = [61.14,61.14,61.19,61.26,61.37,61.40,61.41,61.30,61.28,61.10]#,60.42
bleub2 = [61.01]*len(x)
#KORAN
bleuc1 = [20.42,20.52,20.42,20.37,20.39,20.36,20.33,20.14,19.75,19.49]#,18.60
bleuc2 = [20.4]*len(x)
#MEDICAL
bleud1 = [54.39,54.26,54.36,54.36,53.94,53.97,53.79,54.26,54.31,54.15]#,52.63
bleud2 = [54.19]*len(x)


fig, axs = plt.subplots(2, 2)

# 创建折线图
axs[0,0].plot(x, bleua1, label='w/ CF', marker='o')  # 第一条线
axs[0,0].plot(x, bleua2, label='w/o CF', linestyle='--')  # 第二条线

# 添加标题和轴标签
axs[0,0].set_title('IT')
# axs[0,0].xlabel('k')
# axs[0,0].ylabel('bleu')

axs[0,1].plot(x, bleub1, label='w/ CF', marker='o')  # 第一条线
axs[0,1].plot(x, bleub2, label='w/o CF', linestyle='--')  # 第二条线
axs[0,1].set_title('Law')

axs[1,0].plot(x, bleuc1, label='w/ CF', marker='o')  # 第一条线
axs[1,0].plot(x, bleuc2, label='w/o CF', linestyle='--')  # 第二条线
axs[1,0].set_title('Koran')

axs[1,1].plot(x, bleud1, label='w/ CF', marker='o')  # 第一条线
axs[1,1].plot(x, bleud2, label='w/o CF', linestyle='--')  # 第二条线

axs[1,1].set_title('Medical')
# # axs[0,0].legend(loc='upper right')
# # axs[0,1].legend(loc='upper right')
# # axs[1,0].legend(loc='upper right')
axs[1,1].legend(loc='lower right')
# 显示图例
plt.subplots_adjust(hspace=0.3, wspace=0.3)
plt.legend()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设置随机数种子以获得可重现的结果
np.random.seed(39)

# 生成95个红色点
red_points = np.random.rand(190, 2)  # 生成一个95x2的数组，每行代表一个点的x和y坐标

# 生成第一个蓝色点
blue_point = np.random.rand(1, 2)  # 生成一个1x2的数组，代表第一个蓝色点的x和y坐标

# 在第一个蓝色点的附近生成剩余的4个蓝色点
# 我们通过在第一个蓝色点周围添加一些小的随机偏移来实现这一点
offsets = np.random.normal(loc=0, scale=0.10, size=(9, 2))  # 生成4x2的数组，每行代表偏移量
blue_points = blue_point + offsets  # 在第一个蓝色点的基础上添加偏移量以生成剩余的蓝色点
blue_points = np.vstack([blue_point, blue_points])  # 将第一个蓝色点和其余蓝色点合并


# 设置图的大小
plt.figure(figsize=(4, 3))

top_blue_point = blue_points[blue_points[:, 1].argmax()]

# 设置圆的半径
radius = 0.1



circle_center = np.array([0.5, 0.5])
circle_radius = 0.5

# 过滤掉圆外的红色点
red_points_inside = np.array([point for point in red_points if np.linalg.norm(point - circle_center) < circle_radius])

# 过滤掉圆外的蓝色点
blue_points_inside = np.array([point for point in blue_points if np.linalg.norm(point - circle_center) < circle_radius])

# 找到从上往下数第二个蓝色点
sorted_blue_points = blue_points[np.argsort(-blue_points[:, 1])]  # 对蓝色点按y坐标降序排序
second_top_blue_point = sorted_blue_points[1]  # 从上往下数第二个蓝色点





# 重新绘制图表
plt.figure(figsize=(4, 4))
plt.scatter(red_points_inside[:, 0], red_points_inside[:, 1], color='green', s=10, alpha=0.6)
plt.scatter(blue_points_inside[:, 0], blue_points_inside[:, 1], color='blue', s=10, alpha=0.6)
plt.scatter(second_top_blue_point[0], second_top_blue_point[1], color='red', s=10, alpha=1)

# 添加以从上往下数第二个蓝色点为圆心的虚线圆
circle = plt.Circle(second_top_blue_point, radius, color='blue', fill=False, linestyle='--', linewidth=0.9)
plt.gca().add_artist(circle)



# 设置图表为圆形虚线边框
plt.gca().set_aspect('equal', adjustable='box')
plt.gca().add_patch(plt.Circle(circle_center, circle_radius, color='black', fill=False, linestyle='--', linewidth=1.5))

# 隐藏坐标轴刻度
plt.xticks([])
plt.yticks([])

# 隐藏坐标轴的边框线
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()
plt.savefig('pic4.svg')

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(55)
# 设置图像大小和去掉坐标轴
plt.figure(figsize=(4, 4))

ax = plt.gca()
ax.axis('off')

# 绘制黑色圆形虚线边框
circle = plt.Circle((0.5, 0.5), 0.5, color='black', fill=False, linestyle='--')
ax.add_artist(circle)

# 随机生成160个绿色点和40个蓝色点
for _ in range(160):
    x, y = np.random.uniform(0, 1, 2)
    if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
        plt.plot(x, y, 'yo', markersize=2)
for _ in range(40):
    x, y = np.random.uniform(0, 1, 2)
    if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
        plt.plot(x, y, 'bo', markersize=2)
for _ in range(30):
    x, y = np.random.uniform(0, 1, 2)
    if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
        plt.plot(x, y, 'go', markersize=2)
for _ in range(30):
    x, y = np.random.uniform(0, 1, 2)
    if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
        plt.plot(x, y, 'ko', markersize=2)

# 在中央红色点周围随机分布20个蓝色点
for _ in range(10):
    angle = np.random.uniform(0, 2*np.pi)
    r = np.random.uniform(0, 0.1)  # 控制蓝色点分布在红色点周围的范围
    x = 0.5 + r * np.cos(angle)
    y = 0.5 + r * np.sin(angle)
    if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
        plt.plot(x, y, 'bo', markersize=2)

# 绘制中央的红色点
plt.plot(0.5, 0.5, 'ro', markersize=4,alpha=1)
radius1 = 0.07
circle = plt.Circle((0.5,0.5), radius1, color='blue', fill=False, linestyle='--', linewidth=0.9)
plt.gca().add_artist(circle)#k=8

radius1 = 0.13
circle = plt.Circle((0.5,0.5), radius1, color='brown', fill=False, linestyle='--', linewidth=0.9)
plt.gca().add_artist(circle)#k=20

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(55)
# 设置图像大小和去掉坐标轴
plt.figure(figsize=(4, 4))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # 调整边界留白

ax = plt.gca()
ax.axis('off')

# 绘制黑色圆形虚线边框
circle = plt.Circle((0.5, 0.5), 0.5, color='black', fill=False, linestyle='--')
ax.add_artist(circle)

# 随机生成点
colors = ['go', 'bo', 'ko', 'yo', 'orange']  # 使用列表简化点的生成过程
for color in colors:
    for _ in range(30):
        x, y = np.random.uniform(0, 1, 2)
        if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
            plt.plot(x, y, color, markersize=2)

# 绘制中央的红色点和两个圆环
plt.plot(0.5, 0.5, 'ro', markersize=4, alpha=1)
for radius, line_color in zip([0.04, 0.15], ['blue', 'brown']):
    circle = plt.Circle((0.5, 0.5), radius, color=line_color, fill=False, linestyle='--', linewidth=0.9)
    ax.add_artist(circle)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(55)
# 设置图像大小和去掉坐标轴
plt.figure(figsize=(4, 4))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # 调整边界留白

ax = plt.gca()
ax.axis('off')

# 绘制黑色圆形虚线边框
circle = plt.Circle((0.5, 0.5), 0.5, color='black', fill=False, linestyle='--')
ax.add_artist(circle)

# 随机生成点
colors = ['go', 'bo']  # 使用列表简化点的生成过程
for color in colors:
    for _ in range(10):
        x, y = np.random.uniform(0, 1, 2)
        if ((x-0.5)**2 + (y-0.5)**2 <= 0.5**2):
            plt.plot(x, y, color, markersize=10)

# 绘制中央的红色点和两个圆环
plt.plot(0.5, 0.5, 'ro', markersize=4, alpha=1)
for radius, line_color in zip([0.04, 0.15], ['blue', 'brown']):
    circle = plt.Circle((0.5, 0.5), radius, color=line_color, fill=False, linestyle='--', linewidth=0.9)
    ax.add_artist(circle)

plt.show()

# %%
# 设置图的大小
plt.figure(figsize=(4, 3))

top_blue_point = blue_points[blue_points[:, 1].argmax()]

# 设置圆的半径
radius = 0.15

# 再次绘制点
plt.figure(figsize=(3, 3))
plt.scatter(red_points[:, 0], red_points[:, 1], color='red', s=10, label='Red Points', alpha=0.6)
plt.scatter(blue_points[:, 0], blue_points[:, 1], color='blue', s=10, label='Blue Points', alpha=0.6)

# 添加虚线圆
circle = plt.Circle(top_blue_point, radius, color='blue', fill=False, linestyle='--')
plt.gca().add_artist(circle)

# 设置图表元素
plt.legend()
plt.title('Random Points Distribution with Circle')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号
# 假设的数据
x = [1,2,3,4,5,6]#,2  # 横轴数据
#IT
bleua1 = [46.63,46.22,46.26,46.61,46.00,46.26]
bleub1 = [61.69,61.73,61.66,61.67,61.74,61.71]
bleuc1 = [20.74,20.55,20.39,20.79,20.55,20.52]
bleud1 = [54.84,54.74,54.52,54.68,54.10,54.69]
fig, axs = plt.subplots(2, 2)

# 创建折线图
axs[0,0].plot(x, bleua1, label='w/ CF', marker='o')  # 第一条线
#axs[0,0].plot(x, bleua2, label='w/o CF', linestyle='--')  # 第二条线

# 添加标题和轴标签
axs[0,0].set_title('IT')
# axs[0,0].xlabel('k')
# axs[0,0].ylabel('bleu')

axs[0,1].plot(x, bleub1, marker='o')  # 第一条线
#axs[0,1].plot(x, bleub2, label='w/o CF', linestyle='--')  # 第二条线
axs[0,1].set_title('Law')

axs[1,0].plot(x, bleuc1,  marker='o')  # 第一条线
#axs[1,0].plot(x, bleuc2, label='w/o CF', linestyle='--')  # 第二条线
axs[1,0].set_title('Koran')

axs[1,1].plot(x, bleud1,  marker='o')  # 第一条线
#axs[1,1].plot(x, bleud2, label='w/o CF', linestyle='--')  # 第二条线

axs[1,1].set_title('Medical')
# # axs[0,0].legend(loc='upper right')
# # axs[0,1].legend(loc='upper right')
# # axs[1,0].legend(loc='upper right')
axs[1,1].legend(loc='lower right')
# 显示图例
plt.subplots_adjust(hspace=0.3, wspace=0.3)
plt.legend()

# 显示图形
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号
# 假设的数据
x = ["A","B","C","D","E","F"]#,2  # 横轴数据
#IT
bleua1 = [46.61,46.00,46.26,46.26,46.22,46.63]

bleub1 = [61.67,61.74,61.66,61.71,61.73,61.76]
bleuc1 = [20.69,20.55,20.39,20.52,20.55,20.74]
bleud1 = [54.68,54.10,54.52,54.69,54.74,54.84]
fig, axs = plt.subplots(1, 4, figsize=(20, 5))  # figsize设置为(20, 5)

# 创建折线图
axs[0].plot(x, bleua1, label='w/ CF', marker='o')  # 第一条线
#axs[0,0].plot(x, bleua2, label='w/o CF', linestyle='--')  # 第二条线

# 添加标题和轴标签
axs[0].set_title('IT')
# axs[0,0].xlabel('k')
# axs[0,0].ylabel('bleu')

axs[1].plot(x, bleub1, marker='o')  # 第一条线
#axs[0,1].plot(x, bleub2, label='w/o CF', linestyle='--')  # 第二条线
axs[1].set_title('Law')

axs[2].plot(x, bleuc1,  marker='o')  # 第一条线
#axs[1,0].plot(x, bleuc2, label='w/o CF', linestyle='--')  # 第二条线
axs[2].set_title('Koran')

axs[3].plot(x, bleud1,  marker='o')  # 第一条线
#axs[1,1].plot(x, bleud2, label='w/o CF', linestyle='--')  # 第二条线

axs[3].set_title('Medical')
# # axs[0,0].legend(loc='upper right')
# # axs[0,1].legend(loc='upper right')
# # axs[1,0].legend(loc='upper right')
axs[3].legend(loc='lower right')
# 显示图例
plt.subplots_adjust(hspace=0.3, wspace=0.3)
plt.legend()

# 显示图形
plt.show()
# Out:
# /tmp/ipykernel_162923/3500491629.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
